# %%
from ax.api.client import Client
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from SamplingMethods import Sampler_class
import plotly.express as px

# %% [markdown]
# # Model Mk4

# %%
client = Client()
client = client.load_from_json_file("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/Modelling/ModelMk4.json")
client.get_next_trials(max_trials=1)
n = 10
iCoords_arr = np.linspace(0,1,n-1)
jCoords_arr = np.linspace(0,1,n-1)
kCoords_arr = np.linspace(0,1,n-1)
ijkCoordsOld_lis = []
ijkCoords_lis = []
for i in iCoords_arr:
    for j in jCoords_arr:
        for k in kCoords_arr:
            ijkCoordsOld_lis.append([i,j,k])
            ijkCoords_lis.append({"s1":i,"s2":j,"b1":k})
y_pred = client.predict(ijkCoords_lis)
y_pred_lis = []
for i in y_pred:
    y_pred_lis.append(i["t1"][0])
ijkCoordsOld_arr = np.array(ijkCoordsOld_lis)
y_pred_arr = np.array(y_pred_lis)
df2 = pd.DataFrame({'s1': ijkCoordsOld_arr[:, 0],'s2': ijkCoordsOld_arr[:, 1],'b1': ijkCoordsOld_arr[:, 2], 'y_pred': y_pred_arr})

fig = px.scatter_3d(df2, x='s1', y='s2', z='b1', color='y_pred')
fig.show()
# Out:
# /Users/thomasdodd/miniconda3/envs/Ax1_env/lib/python3.12/site-packages/linear_operator/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(

# %%
Bayes_9_27_1_Prior1 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-1.pkl")[0].tolist()
Bayes_9_27_1_Prior2 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-2.pkl")[0].tolist()
Bayes_9_27_1_Prior3 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-3.pkl")[0].tolist()
Bayes_9_27_1_Prior4 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-4.pkl")[0].tolist()
Bayes_9_27_1_Prior5 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-5.pkl")[0].tolist()
Bayes_9_27_1_Prior6 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-6.pkl")[0].tolist()
Bayes_9_27_1_Prior7 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-7.pkl")[0].tolist()
Bayes_9_27_1_Prior8 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-8.pkl")[0].tolist()
Bayes_9_27_1_Prior9 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-9.pkl")[0].tolist()
Bayes_9_27_1_Prior10 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-10.pkl")[0].tolist()
Bayes_9_27_1_Prior11 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-11.pkl")[0].tolist()
Bayes_9_27_1_Prior12 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-12.pkl")[0].tolist()
Bayes_9_27_1_Prior13 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-13.pkl")[0].tolist()
Bayes_9_27_1_Prior14 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-14.pkl")[0].tolist()
Bayes_9_27_1_Prior15 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-15.pkl")[0].tolist()
Bayes_9_27_1_Prior16 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-16.pkl")[0].tolist()
Bayes_9_27_1_Prior17 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-17.pkl")[0].tolist()
Bayes_9_27_1_Prior18 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-18.pkl")[0].tolist()
Bayes_9_27_1_Prior19 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-19.pkl")[0].tolist()
Bayes_9_27_1_Prior20 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-20.pkl")[0].tolist()
Bayes_9_27_1_Prior21 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-21.pkl")[0].tolist()
Bayes_9_27_1_Prior22 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-22.pkl")[0].tolist()
Bayes_9_27_1_Prior23 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-23.pkl")[0].tolist()
Bayes_9_27_1_Prior24 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-24.pkl")[0].tolist()
Bayes_9_27_1_Prior25 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-25.pkl")[0].tolist()
Bayes_9_27_1_Prior26 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-26.pkl")[0].tolist()
Bayes_9_27_1_Prior27 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/SequentialTestingOfSamplingTechnique/DataGenerated/BOpt-EI-9,27,1-27.pkl")[0].tolist()

all_lis = [Bayes_9_27_1_Prior1,Bayes_9_27_1_Prior2,Bayes_9_27_1_Prior3,Bayes_9_27_1_Prior4,Bayes_9_27_1_Prior5,Bayes_9_27_1_Prior6,Bayes_9_27_1_Prior7,Bayes_9_27_1_Prior8,Bayes_9_27_1_Prior9,Bayes_9_27_1_Prior10,Bayes_9_27_1_Prior11,Bayes_9_27_1_Prior12,Bayes_9_27_1_Prior13,Bayes_9_27_1_Prior14,Bayes_9_27_1_Prior15,Bayes_9_27_1_Prior16,Bayes_9_27_1_Prior17,Bayes_9_27_1_Prior18,Bayes_9_27_1_Prior19,Bayes_9_27_1_Prior20,Bayes_9_27_1_Prior21,Bayes_9_27_1_Prior22,Bayes_9_27_1_Prior23,Bayes_9_27_1_Prior24,Bayes_9_27_1_Prior25,Bayes_9_27_1_Prior26,Bayes_9_27_1_Prior27]

for counter,i in enumerate(all_lis):
    print(counter+1,len(i))
# Out:
# 1 1000
# 2 1000
# 3 1000
# 4 1000
# 5 1000
# 6 1000
# 7 1000
# 8 1000
# 9 1000
# 10 1000
# 11 1000
# 12 1000
# 13 1000
# 14 1000
# 15 1000
# 16 1000
# 17 1000
# 18 1000
# 19 1000
# 20 1000
# 21 1000
# 22 1000
# 23 1000
# 24 1000
# 25 1000
# 26 1000
# 27 1000

# %%
from matplotlib.pyplot import figure

figure(figsize=(20, 9), dpi=80)

bound = 1000

Bayes_9_27_1_Prior1_bounded = Bayes_9_27_1_Prior1[0:bound]
Bayes_9_27_1_Prior2_bounded = Bayes_9_27_1_Prior2[0:bound]
Bayes_9_27_1_Prior3_bounded = Bayes_9_27_1_Prior3[0:bound]
Bayes_9_27_1_Prior4_bounded = Bayes_9_27_1_Prior4[0:bound]
Bayes_9_27_1_Prior5_bounded = Bayes_9_27_1_Prior5[0:bound]
Bayes_9_27_1_Prior6_bounded = Bayes_9_27_1_Prior6[0:bound]
Bayes_9_27_1_Prior7_bounded = Bayes_9_27_1_Prior7[0:bound]
Bayes_9_27_1_Prior8_bounded = Bayes_9_27_1_Prior8[0:bound]
Bayes_9_27_1_Prior9_bounded = Bayes_9_27_1_Prior9[0:bound]
Bayes_9_27_1_Prior10_bounded = Bayes_9_27_1_Prior10[0:bound]
Bayes_9_27_1_Prior11_bounded = Bayes_9_27_1_Prior11[0:bound]
Bayes_9_27_1_Prior12_bounded = Bayes_9_27_1_Prior12[0:bound]
Bayes_9_27_1_Prior13_bounded = Bayes_9_27_1_Prior13[0:bound]
Bayes_9_27_1_Prior14_bounded = Bayes_9_27_1_Prior14[0:bound]
Bayes_9_27_1_Prior1_name = []
Bayes_9_27_1_Prior2_name = []
Bayes_9_27_1_Prior3_name = []
Bayes_9_27_1_Prior4_name = []
Bayes_9_27_1_Prior5_name = []
Bayes_9_27_1_Prior6_name = []
Bayes_9_27_1_Prior7_name = []
Bayes_9_27_1_Prior8_name = []
Bayes_9_27_1_Prior9_name = []
Bayes_9_27_1_Prior10_name = []
Bayes_9_27_1_Prior11_name = []
Bayes_9_27_1_Prior12_name = []
Bayes_9_27_1_Prior13_name = []
Bayes_9_27_1_Prior14_name = []
Bayes_9_27_1_Prior15_name = []
Bayes_9_27_1_Prior16_name = []
Bayes_9_27_1_Prior17_name = []
Bayes_9_27_1_Prior18_name = []
Bayes_9_27_1_Prior19_name = []
Bayes_9_27_1_Prior20_name = []
Bayes_9_27_1_Prior21_name = []
Bayes_9_27_1_Prior22_name = []
Bayes_9_27_1_Prior23_name = []
Bayes_9_27_1_Prior24_name = []
Bayes_9_27_1_Prior25_name = []
Bayes_9_27_1_Prior26_name = []
Bayes_9_27_1_Prior27_name = []
for i in range(len(Bayes_9_27_1_Prior1_bounded)):
    Bayes_9_27_1_Prior1_name.append("PR1\n1,27,1")
    Bayes_9_27_1_Prior2_name.append("PR2\n2,27,1")
    Bayes_9_27_1_Prior3_name.append("PR3\n3,27,1")
    Bayes_9_27_1_Prior4_name.append("PR4\n4,27,1")
    Bayes_9_27_1_Prior5_name.append("PR5\n5,27,1")
    Bayes_9_27_1_Prior6_name.append("PR6\n6,27,1")
    Bayes_9_27_1_Prior7_name.append("PR7\n7,27,1")
    Bayes_9_27_1_Prior8_name.append("PR8\n8,27,1")
    Bayes_9_27_1_Prior9_name.append("PR9\n9,27,1")
    Bayes_9_27_1_Prior10_name.append("PR10\n10,27,1")
    Bayes_9_27_1_Prior11_name.append("PR11\n11,27,1")
    Bayes_9_27_1_Prior12_name.append("PR12\n12,27,1")
    Bayes_9_27_1_Prior13_name.append("PR13\n13,27,1")
    Bayes_9_27_1_Prior14_name.append("PR14\n14,27,1")
    Bayes_9_27_1_Prior15_name.append("PR15\n15,27,1")
    Bayes_9_27_1_Prior16_name.append("PR16\n16,27,1")
    Bayes_9_27_1_Prior17_name.append("PR17\n17,27,1")
    Bayes_9_27_1_Prior18_name.append("PR18\n18,27,1")
    Bayes_9_27_1_Prior19_name.append("PR19\n19,27,1")
    Bayes_9_27_1_Prior20_name.append("PR20\n20,27,1")
    Bayes_9_27_1_Prior21_name.append("PR21\n21,27,1")
    Bayes_9_27_1_Prior22_name.append("PR22\n22,27,1")
    Bayes_9_27_1_Prior23_name.append("PR23\n23,27,1")
    Bayes_9_27_1_Prior24_name.append("PR24\n24,27,1")
    Bayes_9_27_1_Prior25_name.append("PR25\n25,27,1")
    Bayes_9_27_1_Prior26_name.append("PR26\n26,27,1")
    Bayes_9_27_1_Prior27_name.append("PR27\n27,27,0")

all_names = Bayes_9_27_1_Prior1_name+Bayes_9_27_1_Prior2_name+Bayes_9_27_1_Prior3_name+Bayes_9_27_1_Prior4_name+Bayes_9_27_1_Prior5_name+Bayes_9_27_1_Prior6_name+Bayes_9_27_1_Prior7_name+Bayes_9_27_1_Prior8_name+Bayes_9_27_1_Prior9_name+Bayes_9_27_1_Prior10_name+Bayes_9_27_1_Prior11_name+Bayes_9_27_1_Prior12_name+Bayes_9_27_1_Prior13_name+Bayes_9_27_1_Prior14_name+Bayes_9_27_1_Prior15_name+Bayes_9_27_1_Prior16_name+Bayes_9_27_1_Prior17_name+Bayes_9_27_1_Prior18_name+Bayes_9_27_1_Prior19_name+Bayes_9_27_1_Prior20_name+Bayes_9_27_1_Prior21_name+Bayes_9_27_1_Prior22_name+Bayes_9_27_1_Prior23_name+Bayes_9_27_1_Prior24_name+Bayes_9_27_1_Prior25_name+Bayes_9_27_1_Prior26_name+Bayes_9_27_1_Prior27_name

ndf = pd.DataFrame({"y":all,"type":all_names})
ndf

plt.rcParams["figure.figsize"] = (20,4)
sns.set_theme(style="whitegrid")
# ax = sns.stripplot(x="type", y="y", data=ndf, size=1)
ax = sns.swarmplot(x="type", y="y", data=ndf, size=0.6)
# ax = sns.boxplot(x="type", y="y", data=ndf)
df_means = ndf.groupby("type")["y"].agg("mean").reset_index()
xlim = ax.get_xlim()
ylim = ax.get_ylim()
sns.scatterplot(x="type", y="y", marker='X', color='black', s=100, zorder=3, ax=ax, legend=False, data=df_means)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
plt.title(f"Optimising ModelMk4: {len(Bayes_9_27_1_Prior1_bounded)} Trials")
plt.xlabel("Optimisation Type")
plt.ylabel("Best Mass Loss (%)")
plt.show()

# %%
Threshold = 18
SimulationNumberOfPointsExceedingThreshold = []
PercentageOfPointsExceedingThreshold = []
for simulation in all_lis:
    counter = 0
    for i in simulation:
        if i > Threshold:
            counter+=1
    SimulationNumberOfPointsExceedingThreshold.append(counter)
    PercentageOfPointsExceedingThreshold.append(round((counter/len(simulation))*100,2))
print(SimulationNumberOfPointsExceedingThreshold)
print(PercentageOfPointsExceedingThreshold)
plt.bar(names,SimulationNumberOfPointsExceedingThreshold)
# Out:
# [48, 65, 82, 77, 70, 110, 86, 74, 84, 97, 101, 80, 72, 65, 80, 74, 64, 61, 55, 40, 23, 21, 17, 5, 5, 6, 2]
# [4.8, 6.5, 8.2, 7.7, 7.0, 11.0, 8.6, 7.4, 8.4, 9.7, 10.1, 8.0, 7.2, 6.5, 8.0, 7.4, 6.4, 6.1, 5.5, 4.0, 2.3, 2.1, 1.7, 0.5, 0.5, 0.6, 0.2]
# <BarContainer object of 27 artists>
