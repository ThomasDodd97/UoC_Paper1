# %%
from PIL import Image

# %%
image = Image.open("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/ImageWork/PolymerisableRange.tiff")
image
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=4000x2203>

# %%
print(image.info['dpi'])
# Out:
# (800.0, 800.0)
