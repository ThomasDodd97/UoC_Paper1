# %%
from PIL import Image

# %%
image = Image.open("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Images/BayesianPriorsAbbreviated.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=703x632>

# %%
width, height = image.size
width
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 width, height = im.size
#       2 width
#
# NameError: name 'im' is not defined

# %%
image.save("BayesianPriorsAbbreviated.pdf")
