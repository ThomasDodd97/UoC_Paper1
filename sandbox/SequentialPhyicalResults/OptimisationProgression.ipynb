# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Grid Search
GrdSrchSamples_sca = 27
GrdSrch_df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/Project-1_BO4BT/ExperimentalSeries-1_PGXOpt/Part-C_HypOptComp_PGCI/Part-C1_PGCI-GrdSrch-[27]-P3O1/raw-data_2023-04-11_Stykke4.csv")
GrdSrchMax_sca = -1 * np.min(np.array(GrdSrch_df["DeltaPolymerMass_pct"]))
GrdSrchAvg_sca = -1 * np.average(np.array(GrdSrch_df["DeltaPolymerMass_pct"]))
GrdSrchStd_sca = np.std(np.array(GrdSrch_df["DeltaPolymerMass_pct"]))

print(GrdSrchSamples_sca)
print(GrdSrchMax_sca)
print(GrdSrchAvg_sca)
print(GrdSrchStd_sca)
# Out:
# 27
# 16.242494802522316
# 11.929309387656307
# 1.6559703927279927

# %%
# Sobol Search
SobSrchSamples_sca = 27
SobSrch_df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/Project-1_BO4BT/ExperimentalSeries-1_PGXOpt/Part-C_HypOptComp_PGCI/Part-C3_PGCI-SobSrch-[27]-P3O1/raw-data_2023-04-11_Stykke4.csv")
SobSrchMax_sca = -1 * np.min(np.array(SobSrch_df["DeltaPolymerMass_pct"]))
SobSrchAvg_sca = -1 * np.average(np.array(SobSrch_df["DeltaPolymerMass_pct"]))
SobSrchStd_sca = np.std(np.array(SobSrch_df["DeltaPolymerMass_pct"]))

print(SobSrchSamples_sca)
print(SobSrchMax_sca)
print(SobSrchAvg_sca)
print(SobSrchStd_sca)
# Out:
# 27
# 14.549080458888582
# 12.33530021963376
# 1.4308223650110772

# %%
# Random Search
RndSrchSamples_sca = 27
RndSrch_df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/Project-1_BO4BT/ExperimentalSeries-1_PGXOpt/Part-C_HypOptComp_PGCI/Part-A2_PGCI-RndSrch-[27]-P3O1/raw-data_2023-03-10_PtA2-PGCI-RndSrch-[27]-P3O1_Stykke-4.csv")
RndSrchMax_sca = -1 * np.min(np.array(RndSrch_df["delta_polymer_mass_pct"]))
RndSrchAvg_sca = -1 * np.average(np.array(RndSrch_df["delta_polymer_mass_pct"]))
RndSrchStd_sca = np.std(np.array(RndSrch_df["delta_polymer_mass_pct"]))

print(RndSrchSamples_sca)
print(RndSrchMax_sca)
print(RndSrchAvg_sca)
print(RndSrchStd_sca)
# Out:
# 27
# 14.007758321412112
# 12.544760582315112
# 0.8776451378191571

# %%
# Probability Of Improvement
BOpt_8SP_3It_df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/Project-1_BO4BT/ExperimentalSeries-1_PGXOpt/Part-C_HypOptComp_PGCI/Part-B5_PGCI-BOpt-[8,3,3,3,3,3,3,1]-P3O1/raw-data_2023-03-20_PtB5-PGCI-BOpt-[8,3,3,3,3,3,3,1]-P3O1-Stykke-4.csv")
BOpt_8SP_3It_df["s1"] = BOpt_8SP_3It_df["x1"]
BOpt_8SP_3It_df["s2"] = BOpt_8SP_3It_df["x2"]
BOpt_8SP_3It_df["b1"] = BOpt_8SP_3It_df["x3"]
BOpt_8SP_3It_df["DeltaPolymerMassPositive_pct"] = BOpt_8SP_3It_df["delta_polymer_mass_pct"]*-1
BOpt_8SP_3It_df
# Out:
#    mould_position  G_stoichiometry  CA_stoichiometry  IA_stoichiometry  \
# 0              A1              1.0          0.989354          0.502368
# 1              A2              1.0          0.138614          1.034845
# 2              A3              1.0          0.470234          0.569463
# 3              A4              1.0          1.695973          0.036986
# 4              A5              1.0          0.676664          0.786529
# 5              A6              1.0          0.999834          0.254052
# 6              B1              1.0          0.081259          1.763554
# 7              B2              1.0          0.931999          0.582790
# 8              B3              1.0          0.091500          1.218500
# 9              B4              1.0          1.345100          0.012800
# 10             B5              1.0          1.335700          0.005500
# 11             B6              1.0          0.144200          1.266400
# 12             C1              1.0          0.151100          0.943300
# 13             C2              1.0          0.139500          1.010900
# 14             C3              1.0          0.144400          0.804700
# 15             C4              1.0          0.143800          0.881000
# 16             C5              1.0          0.128700          0.795600
# 17             C6              1.0          0.942900          0.545300
# 18             D1              1.0          0.927500          0.539000
# 19             D2              1.0          0.984800          0.528500
# 20             D3              1.0          0.812100          0.687600
# 21             D4              1.0          0.801900          0.660900
# 22             D5              1.0          0.777300          0.714400
# 23             D6              1.0          0.752800          0.833600
# 24             E1              1.0          0.668700          0.840700
# 25             E2              1.0          0.719800          0.788300
# 26             E3              1.0          0.833300          0.372000
# 27             E4              1.0          0.773000          0.376600
# 28             E5              1.0          0.777400          0.373800
#
#           x1        x2        x3  polymer_start_mass_g  polymer_end_mass_pct  \
# 0   0.574273  0.838241  0.726713                  2.92             86.558126
# 1   0.074273  0.338241  0.226713                  3.38             85.987091
# 2   0.324273  0.088241  0.476713                  3.40             86.857362
# 3   0.824273  0.588241  0.976713                  2.86             88.632357
# 4   0.949273  0.213241  0.351713                  3.39             87.159687
# 5   0.449273  0.713241  0.851713                  3.19             86.923355
# 6   0.199273  0.963241  0.101713                  3.19             89.091765
# 7   0.699273  0.463241  0.601713                  3.10             86.234312
# 8   0.080100  0.429500  0.147600                  3.53             89.278178
# 9   0.569800  0.799700  0.992900                  3.03             91.622741
# 10  0.560900  0.305400  0.995800                  3.09             90.881200
# 11  0.079100  0.651300  0.233100                  3.36             88.723825
# 12  0.095800  0.232600  0.234700                  3.37             87.120193
# 13  0.071100  0.312800  0.230000                  3.36             87.475473
# 14  0.111800  0.026700  0.216200                  3.58             86.843673
# 15  0.116800  0.119300  0.212900                  3.41             86.486662
# 16  0.056000  0.020400  0.220300                  3.51             86.605535
# 17  0.679200  0.438100  0.620800                  3.21             87.982575
# 18  0.646300  0.461500  0.631200                  3.22             86.788613
# 19  0.688400  0.478700  0.642600                  3.11             87.576801
# 20  0.626100  0.578200  0.564300                  3.24             85.360793
# 21  0.637900  0.470000  0.550400                  3.14             87.561111
# 22  0.624200  0.557200  0.541200                  3.13             86.562527
# 23  0.532300  0.983900  0.579800                  3.18             88.974175
# 24  0.441300  0.980500  0.575500                  3.21             88.526132
# 25  0.492500  0.881900  0.581100                  3.16             87.482123
# 26  0.382900  0.657900  0.775600                  2.80             83.333167
# 27  0.334900  0.646000  0.771200                  3.25             82.720178
# 28  0.337000  0.647600  0.773100                  3.48             79.224303
#
#     delta_polymer_mass_pct        s1        s2        b1  \
# 0               -13.441874  0.574273  0.838241  0.726713
# 1               -14.012909  0.074273  0.338241  0.226713
# 2               -13.142638  0.324273  0.088241  0.476713
# 3               -11.367643  0.824273  0.588241  0.976713
# 4               -12.840313  0.949273  0.213241  0.351713
# 5               -13.076645  0.449273  0.713241  0.851713
# 6               -10.908235  0.199273  0.963241  0.101713
# 7               -13.765688  0.699273  0.463241  0.601713
# 8               -10.721822  0.080100  0.429500  0.147600
# 9                -8.377259  0.569800  0.799700  0.992900
# 10               -9.118800  0.560900  0.305400  0.995800
# 11              -11.276175  0.079100  0.651300  0.233100
# 12              -12.879807  0.095800  0.232600  0.234700
# 13              -12.524527  0.071100  0.312800  0.230000
# 14              -13.156327  0.111800  0.026700  0.216200
# 15              -13.513338  0.116800  0.119300  0.212900
# 16              -13.394465  0.056000  0.020400  0.220300
# 17              -12.017425  0.679200  0.438100  0.620800
# 18              -13.211387  0.646300  0.461500  0.631200
# 19              -12.423199  0.688400  0.478700  0.642600
# 20              -14.639207  0.626100  0.578200  0.564300
# 21              -12.438889  0.637900  0.470000  0.550400
# 22              -13.437473  0.624200  0.557200  0.541200
# 23              -11.025825  0.532300  0.983900  0.579800
# 24              -11.473868  0.441300  0.980500  0.575500
# 25              -12.517877  0.492500  0.881900  0.581100
# 26              -16.666833  0.382900  0.657900  0.775600
# 27              -17.279822  0.334900  0.646000  0.771200
# 28              -20.775697  0.337000  0.647600  0.773100
#
#     DeltaPolymerMassPositive_pct
# 0                      13.441874
# 1                      14.012909
# 2                      13.142638
# 3                      11.367643
# 4                      12.840313
# 5                      13.076645
# 6                      10.908235
# 7                      13.765688
# 8                      10.721822
# 9                       8.377259
# 10                      9.118800
# 11                     11.276175
# 12                     12.879807
# 13                     12.524527
# 14                     13.156327
# 15                     13.513338
# 16                     13.394465
# 17                     12.017425
# 18                     13.211387
# 19                     12.423199
# 20                     14.639207
# 21                     12.438889
# 22                     13.437473
# 23                     11.025825
# 24                     11.473868
# 25                     12.517877
# 26                     16.666833
# 27                     17.279822
# 28                     20.775697

# %%
# Expected Improvement
ax_BOpt_8SP_3It_df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/Project-1_BO4BT/ExperimentalSeries-1_PGXOpt/Part-C_HypOptComp_PGCI/Part-D3_PGCI-BOpt-9,27,3-S2B1O1/raw-data_2023-03-15_Stykke4.csv")
ax_BOpt_8SP_3It_df["DeltaPolymerMassPositive_pct"] = ax_BOpt_8SP_3It_df["DeltaPolymerMass_pct"]*-1
ax_BOpt_8SP_3It_df
# Out:
#    mould_position  G_stoichiometry  CA_stoichiometry  IA_stoichiometry  \
# 0              A1              1.0          0.989354          0.502368
# 1              A2              1.0          0.138614          1.034845
# 2              A3              1.0          0.470234          0.569463
# 3              A4              1.0          1.695973          0.036986
# 4              A5              1.0          0.676664          0.786529
# 5              A6              1.0          0.999834          0.254052
# 6              B1              1.0          0.081259          1.763554
# 7              B2              1.0          0.931999          0.582790
# 8              B3              1.0          0.528275          0.741425
# 9              B4              1.0          0.414070          0.194428
# 10             B5              1.0          0.295617          0.551447
# 11             B6              1.0          0.663207          0.154200
# 12             C1              1.0          0.457158          0.104212
# 13             C2              1.0          0.478044          0.222409
# 14             C3              1.0          0.500000          0.000000
# 15             C4              1.0          0.489801          0.026951
# 16             C5              1.0          0.487343          0.025314
# 17             C6              1.0          0.500000          0.000000
# 18             D1              1.0          0.690667          0.000000
# 19             D2              1.0          0.500000          0.000000
# 20             D3              1.0          1.127054          0.204863
# 21             D4              1.0          0.500000          0.000000
# 22             D5              1.0          0.500000          0.000000
# 23             D6              1.0          2.000000          0.000000
# 24             E1              1.0          0.597570          0.000000
# 25             E2              1.0          1.568392          0.431608
# 26             E3              1.0          0.461904          0.108026
# 27             E4              1.0          0.000000          1.000000
# 28             E5              1.0          0.000000          1.841916
#
#           s1        s2        b1  StartPolymerMass_g  EndPolymerMass_pct  \
# 0   0.574273  0.838241  0.726713                2.92           86.558126
# 1   0.074273  0.338241  0.226713                3.38           85.987091
# 2   0.324273  0.088241  0.476713                3.40           86.857362
# 3   0.824273  0.588241  0.976713                2.86           88.632357
# 4   0.949273  0.213241  0.351713                3.39           87.159687
# 5   0.449273  0.713241  0.851713                3.19           86.923355
# 6   0.199273  0.963241  0.101713                3.19           89.091765
# 7   0.699273  0.463241  0.601713                3.10           86.234312
# 8   0.367431  0.490512  0.497430                3.29           86.900726
# 9   0.000000  0.131310  0.171861                3.12           85.331179
# 10  0.000000  0.349052  0.408767                3.48           88.098928
# 11  0.180467  0.105572  0.139475                3.11           85.909610
# 12  0.000000  0.216229  0.085685                3.49           84.795072
# 13  0.076517  0.000000  0.222409                3.17           85.882807
# 14  0.000000  0.130815  0.000000                3.13           83.363601
# 15  0.000000  0.321289  0.020398                3.53           82.014853
# 16  0.000000  0.000000  0.025314                3.44           84.338759
# 17  0.000000  0.350934  0.000000                3.46           84.962705
# 18  0.127111  0.325983  0.000000                3.70           86.462789
# 19  0.000000  0.438756  0.000000                3.47           83.954244
# 20  0.611623  0.000000  0.204863                3.13           87.996295
# 21  0.000000  0.234873  0.000000                4.24           85.360702
# 22  0.000000  0.000000  0.000000                3.33           84.310627
# 23  1.000000  1.000000  0.000000                2.98           89.641380
# 24  0.065047  0.000000  0.000000                3.31           85.040221
# 25  1.000000  1.000000  0.215804                3.02           88.567042
# 26  0.000000  0.417798  0.076193                3.30           85.169882
# 27  0.226499  0.000000  1.000000                3.33           87.446276
# 28  0.024033  0.841916  1.000000                3.24           90.509550
#
#     DeltaPolymerMass_pct  DeltaPolymerMassPositive_pct
# 0             -13.441874                     13.441874
# 1             -14.012909                     14.012909
# 2             -13.142638                     13.142638
# 3             -11.367643                     11.367643
# 4             -12.840313                     12.840313
# 5             -13.076645                     13.076645
# 6             -10.908235                     10.908235
# 7             -13.765688                     13.765688
# 8             -13.099274                     13.099274
# 9             -14.668821                     14.668821
# 10            -11.901072                     11.901072
# 11            -14.090390                     14.090390
# 12            -15.204928                     15.204928
# 13            -14.117193                     14.117193
# 14            -16.636399                     16.636399
# 15            -17.985147                     17.985147
# 16            -15.661241                     15.661241
# 17            -15.037295                     15.037295
# 18            -13.537211                     13.537211
# 19            -16.045756                     16.045756
# 20            -12.003705                     12.003705
# 21            -14.639298                     14.639298
# 22            -15.689373                     15.689373
# 23            -10.358620                     10.358620
# 24            -14.959779                     14.959779
# 25            -11.432958                     11.432958
# 26            -14.830118                     14.830118
# 27            -12.553724                     12.553724
# 28             -9.490450                      9.490450

# %%
PI_8SP_3It_Progression = []
PI_8SP_3It_Progression.append(np.max(np.array(BOpt_8SP_3It_df["DeltaPolymerMassPositive_pct"].tolist()[0:8])))
for i in BOpt_8SP_3It_df["DeltaPolymerMassPositive_pct"].tolist()[8::]:
    ToBeat = np.max(np.array(PI_8SP_3It_Progression))
    if i > ToBeat:
        PI_8SP_3It_Progression.append(i)
    else:
        PI_8SP_3It_Progression.append(ToBeat)
PI_8SP_3It_ProgressionIndex = BOpt_8SP_3It_df.index.tolist()[7::]
PI_8SP_3It_ProgressionIndexPlusOne = [x+1 for x in PI_8SP_3It_ProgressionIndex]

# %%
EI_8SP_3It_Progression = []
EI_8SP_3It_Progression.append(np.max(np.array(ax_BOpt_8SP_3It_df["DeltaPolymerMassPositive_pct"].tolist()[0:8])))
for i in ax_BOpt_8SP_3It_df["DeltaPolymerMassPositive_pct"].tolist()[8::]:
    ToBeat = np.max(np.array(EI_8SP_3It_Progression))
    if i > ToBeat:
        EI_8SP_3It_Progression.append(i)
    else:
        EI_8SP_3It_Progression.append(ToBeat)
EI_8SP_3It_ProgressionIndex = ax_BOpt_8SP_3It_df.index.tolist()[7::]
EI_8SP_3It_ProgressionIndexPlusOne = [x+1 for x in EI_8SP_3It_ProgressionIndex]

# %%
PI_8SP_3It_ProgressionIndexPlusOneByThree = []
PI_8SP_3It_ProgressionByThree = []
for counter,(i,j) in enumerate(zip(PI_8SP_3It_ProgressionIndexPlusOne,PI_8SP_3It_Progression)):
    if float(counter+3)%3 == 0.0:
        PI_8SP_3It_ProgressionIndexPlusOneByThree.append(i)
        PI_8SP_3It_ProgressionByThree.append(j)

# %%
EI_8SP_3It_ProgressionIndexPlusOneByThree = []
EI_8SP_3It_ProgressionByThree = []
for counter,(i,j) in enumerate(zip(EI_8SP_3It_ProgressionIndexPlusOne,EI_8SP_3It_Progression)):
    if float(counter+3)%3 == 0.0:
        EI_8SP_3It_ProgressionIndexPlusOneByThree.append(i)
        EI_8SP_3It_ProgressionByThree.append(j)

# %%
plt.plot(PI_8SP_3It_ProgressionIndexPlusOne,PI_8SP_3It_Progression,c="#4c83d0",marker=".")
plt.plot(EI_8SP_3It_ProgressionIndexPlusOne,EI_8SP_3It_Progression,c="#5ea402",marker=".")

plt.scatter(PI_8SP_3It_ProgressionIndexPlusOneByThree,PI_8SP_3It_ProgressionByThree,c="#4c83d0",marker=".",s=150)
plt.scatter(EI_8SP_3It_ProgressionIndexPlusOneByThree,EI_8SP_3It_ProgressionByThree,c="#5ea402",marker=".",s=150)

plt.scatter(PI_8SP_3It_ProgressionIndexPlusOne[19],PI_8SP_3It_Progression[19],c="#4c83d0",marker="X",s=100,edgecolors="black")
plt.scatter(EI_8SP_3It_ProgressionIndexPlusOne[19],EI_8SP_3It_Progression[19],c="#5ea402",marker="X",s=100,edgecolors="black")
plt.scatter(27,GrdSrchMax_sca,color="#FF0000",marker="X",s=100,edgecolors="black")
plt.scatter(27,SobSrchMax_sca,color="#F8531C",marker="X",s=100,edgecolors="black")
plt.scatter(27,RndSrchMax_sca,color="#F0A638",marker="X",s=100,edgecolors="black")

plt.hlines(GrdSrchMax_sca,0,27,linestyle="dashed",alpha=0.3,color="#FF0000")
plt.hlines(SobSrchMax_sca,0,27,linestyle="dashed",alpha=0.3,color="#F8531C")
plt.hlines(RndSrchMax_sca,0,27,linestyle="dashed",alpha=0.3,color="#F0A638")
plt.vlines(27,0,22,color="black",linestyle="dashed",alpha=0.3)

plt.text(x=27.25,y=16.55,s="PI",color="#4c83d0",alpha=0.8)
plt.text(x=27.25,y=18.15,s="EI",color="#5ea402",alpha=0.8)
plt.text(x=27.25,y=16.12,s="Grid",color="#FF0000",alpha=0.8)
plt.text(x=27.25,y=14.45,s="Quasirandom",color="#F8531C",alpha=0.8)
plt.text(x=27.25,y=13.9,s="Pseudorandom",color="#F0A638",alpha=0.8)
plt.text(x=26.6,y=18.7,s="Sample Limit",color="black",rotation=90,alpha=0.8)

x = []
y = []
plt.hlines(GrdSrchMax_sca,0,0.0000000001,linestyle="dashed",alpha=0.3,color="#000000",label="One-Shot Benchmark")
plt.plot(x,y,c="#000000",label="Sequential Routine",marker=".")
plt.scatter(x,y,marker=".",s=50,c="#000000",label="Sample")
plt.scatter(x,y,marker=".",s=150,c="#000000",label="Iteration")
plt.scatter(PI_8SP_3It_ProgressionIndexPlusOne[0],PI_8SP_3It_Progression[0],c="#000000",marker="s",s=100,label="Initial "+r"$\Delta$m$^\circ_\%$")
plt.scatter(x,y,marker="X",s=100,c="#000000",label="Final "+r"$\Delta$m$^\circ_\%$",edgecolors="black")

plt.gcf().set_size_inches(10, 4)
plt.xticks(np.arange(0, 30+1, 5),minor=False)
plt.xticks(np.arange(0, 30+1, 1.0),minor=True)
plt.yticks(np.arange(0, 30+1, 1.0),minor=True)
plt.xlim(left=7,right=30)
plt.ylim(bottom=13,top=21)
plt.xlabel("Samples, i (#)",fontsize="12")
plt.ylabel(r'Percentage Mass Loss, $\Delta$m$^\circ_\%$ (%)',fontsize="12")
plt.legend(loc='upper left',ncols=3,fontsize="12")
plt.tight_layout()

# %%
PI_8SP_3It_Progression
# Out:
# [np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  np.float64(14.012908907024908),
#  14.639206860407173,
#  np.float64(14.639206860407173),
#  np.float64(14.639206860407173),
#  np.float64(14.639206860407173),
#  np.float64(14.639206860407173),
#  np.float64(14.639206860407173),
#  16.66683313150004,
#  17.279821796929994,
#  20.775696958804065]
