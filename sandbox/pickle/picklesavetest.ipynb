# %%
from types import resolve_bases
import pickle
import numpy as np

# %%
X_train = np.array([0,3,6,5,3])
d = {"X_train": X_train}
print(d)
with open('data.pkl', 'wb') as file:
    pickle.dump(d, file)
# Out:
# {'X_train': array([0, 3, 6, 5, 3])}

# %%
with open('data.pkl', 'rb') as file:
    res = pickle.load(file)
print(res)
# Out:
# {'X_train': array([0, 3, 6, 5, 3])}

# %%
res.get("X_train")
# Out:
# array([0, 3, 6, 5, 3])
