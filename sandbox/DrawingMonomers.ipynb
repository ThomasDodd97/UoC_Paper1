# %%
from rdkit import Chem
from rdkit.Chem import Draw

size = (600, 600)

# %%
# Glycerol
m = Chem.MolFromSmiles('C(C(CO)O)O')
img = Draw.MolToImage(m, size=size)

# %%
# Itaconic Acid
m = Chem.MolFromSmiles('C=C(CC(=O)O)C(=O)O')
img = Draw.MolToImage(m, size=size)

# %%
# Citric Acid
m = Chem.MolFromSmiles('C(C(=O)O)C(CC(=O)O)(C(=O)O)O')
img = Draw.MolToImage(m, size=size)

# %%
# atomColourPalette = []
# for i in range(0,119):
#     atomColourPalette.append([0, 0, 0])
# print(atomColourPalette)
# # drawOpts = atomColourPalette, size (600, 600)
# print(mol.GetNumAtoms())
# print(mol.GetNumBonds())
# print(range(mol.GetNumAtoms()))

# Atoms = []
# for i in range(mol.GetNumAtoms()):
#     Atoms.append(i+1)

# Bonds = []
# for i in range(mol.GetNumBonds()):
#     Bonds.append(i+1)

# img = Draw.MolToImage(mol=m,highlightAtoms=[1,2],highlightBonds=[3,4],options=Draw.MolDrawOptions.useBWAtomPalette)
# img.save('./test.png')

# DictionaryOfAtomsColors = {}
# for i in range(0,199):
#     DictionaryOfAtomsColors.update({int(i): ['0','0','0']}) 

# Draw.MolDrawOptions.setAtomPalette(DictionaryOfAtomsColors)

# item = Draw.debug(mol=m,drawOptions=)
# item = Draw.DebugDraw(mol=m,useBW=True)
# item.save('./test.png')

# Draw.drawOptions().useBWAtomPalette()
mol = Chem.MolFromSmiles("CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=CC=C3)N)C(=O)O)C")
size = (600, 600)
img = Draw.MolToImage(mol=mol,size=size,options=Draw.MolDrawOptions().useBWAtomPalette())
img.save('./test.png')

# %%
imgs = []
d2d = Draw.MolDraw2DCairo(350,300)
imgs.append(show_mol(d2d,doravirine,legend='default palette'))

d2d = Draw.MolDraw2DCairo(350,300)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
imgs.append(show_mol(d2d,doravirine,legend='BW palette'))

d2d = Draw.MolDraw2DCairo(350,300)
dopts = d2d.drawOptions()
# use a custom palette where C is purple
dopts.updateAtomPalette({6:(.7,0,.7)})
imgs.append(show_mol(d2d,doravirine,legend='custom palette'))

show_images(imgs)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdDepictor
import rdkit
print(rdkit.__version__)
# Out:
# 2024.09.6

# %%
doravirine = Chem.MolFromSmiles('Cn1c(n[nH]c1=O)Cn2ccc(c(c2=O)Oc3cc(cc(c3)Cl)C#N)C(F)(F)F')
rdDepictor.Compute2DCoords(doravirine)
rdDepictor.StraightenDepiction(doravirine)
doravirine

# %%
from PIL import Image
from io import BytesIO
def show_mol(d2d,mol,legend='',highlightAtoms=[]):
    d2d.DrawMolecule(mol,legend=legend, highlightAtoms=highlightAtoms)
    d2d.FinishDrawing()
    bio = BytesIO(d2d.GetDrawingText())
    return Image.open(bio)
# Buffer sets the distance apart the images are...
def show_images(imgs,buffer=0):
    height = 0
    width = 0
    for img in imgs:
        height = max(height,img.height)
        width += img.width
    width += buffer*(len(imgs)-1)
    res = Image.new("RGBA",(width,height))
    x = 0
    for img in imgs:
        res.paste(img,(x,0))
        x += img.width + buffer
    return res

# %%
imgs = []
d2d = Draw.MolDraw2DCairo(350,300)
imgs.append(show_mol(d2d,doravirine,legend='default palette'))

d2d = Draw.MolDraw2DCairo(350,300)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
imgs.append(show_mol(d2d,doravirine,legend='BW palette'))

d2d = Draw.MolDraw2DCairo(350,300)
dopts = d2d.drawOptions()
# use a custom palette where C is purple
dopts.updateAtomPalette({6:(.7,0,.7)})
imgs.append(show_mol(d2d,doravirine,legend='custom palette'))

show_images(imgs)
# Out:
# <PIL.Image.Image image mode=RGBA size=1050x300>

# %%
imgs = []


m = Chem.MolFromSmiles('C(C(CO)O)O')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
imgs.append(show_mol(d2d,m,legend='Glycerol'))

m = Chem.MolFromSmiles('C=C(CC(=O)O)C(=O)O')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
imgs.append(show_mol(d2d,m,legend='Itaconic Acid'))

m = Chem.MolFromSmiles('C(C(=O)O)C(CC(=O)O)(C(=O)O)O')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
imgs.append(show_mol(d2d,m,legend='Citric Acid'))

show_images(imgs)
# Out:
# <PIL.Image.Image image mode=RGBA size=900x300>

# %%
imgs = []


m = Chem.MolFromSmiles('C(C(CO)O)O')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.11372549019607843,0.6941176470588235,0.9294117647058824)})
imgs.append(show_mol(d2d,m,legend='Glycerol'))

m = Chem.MolFromSmiles('C=C(CC(=O)O)C(=O)O')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.9215686274509803,0.49019607843137253,0.23529411764705882)})
imgs.append(show_mol(d2d,m,legend='Itaconic Acid'))

m = Chem.MolFromSmiles('C(C(=O)O)C(CC(=O)O)(C(=O)O)O')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.9215686274509803,0.49019607843137253,0.23529411764705882)})
imgs.append(show_mol(d2d,m,legend='Citric Acid'))

show_images(imgs)
# Out:
# <PIL.Image.Image image mode=RGBA size=900x300>
