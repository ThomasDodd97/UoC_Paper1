# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('OCC(O)COC(=O)CC(=C)C(=O)OCC(O)CO.OCC(O)COC(=O)C(=C)CC(O)=O.OC(COC(=O)C(=C)CC(O)=O)COC(=O)C(=C)CC(O)=O>>OC(=O)CC(=C)C(=O)OCC(COC(=O)C(=C)CC(O)=O)OC(=O)C(=C)CC(O)=O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(2200,600)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
Image.open(bio)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2200x600>

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('OCC(O)COC(=O)CC(=C)C(=O)OCC(O)CO.OCC(O)COC(=O)C(=C)CC(O)=O.OC(COC(=O)C(=C)CC(O)=O)COC(=O)C(=C)CC(O)=O>>OC(=O)CC(=C)C(=O)OCC(COC(=O)C(=C)CC(O)=O)OC(=O)C(=C)CC(O)=O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1600,600)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
Image.open(bio)
