# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdDepictor
import rdkit
print(rdkit.__version__)

from PIL import Image
from io import BytesIO
def show_mol(d2d,mol,legend='',highlightAtoms=[]):
    d2d.DrawMolecule(mol,legend=legend, highlightAtoms=highlightAtoms)
    d2d.FinishDrawing()
    bio = BytesIO(d2d.GetDrawingText())
    return Image.open(bio)
# Buffer sets the distance apart the images are...
def show_images(imgs,buffer=0):
    height = 0
    width = 0
    for img in imgs:
        height = max(height,img.height)
        width += img.width
    width += buffer*(len(imgs)-1)
    res = Image.new("RGBA",(width,height))
    x = 0
    for img in imgs:
        res.paste(img,(x,0))
        x += img.width + buffer
    return res
# Out:
# 2025.03.1

# %% [markdown]
# # Poly(Glycerol Citrate) and Poly(Glycerol Citrate Itaconate)

# %%
imgs = []

m = Chem.MolFromSmiles('*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)O-*')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.9215686274509803,0.49019607843137253,0.23529411764705882)})
imgs.append(show_mol(d2d,m,legend='Poly(Glycerol Citrate)'))

m = Chem.MolFromSmiles('*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.9215686274509803,0.49019607843137253,0.23529411764705882)})
imgs.append(show_mol(d2d,m,legend='Poly(Glycerol Citrate Itaconate)'))

show_images(imgs)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x300>

# %%
imgs = []

m = Chem.MolFromSmiles('*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)O-*')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.11372549019607843,0.6941176470588235,0.9294117647058824)})
imgs.append(show_mol(d2d,m,legend='Poly(Glycerol Citrate)'))

m = Chem.MolFromSmiles('*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.11372549019607843,0.6941176470588235,0.9294117647058824)})
imgs.append(show_mol(d2d,m,legend='Poly(Glycerol Citrate Itaconate)'))

show_images(imgs)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x300>

# %%
imgs = []

m = Chem.MolFromSmiles('*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)O-*')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
imgs.append(show_mol(d2d,m,legend='Poly(Glycerol Citrate)'))

m = Chem.MolFromSmiles('*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*')
d2d = Draw.MolDraw2DCairo(300,300)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
imgs.append(show_mol(d2d,m,legend='Poly(Glycerol Citrate Itaconate)'))

show_images(imgs)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x300>

# %% [markdown]
# # Reaction for Poly(Glycerol Citrate Itaconate)

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C=C(CC(=O)O)C(=O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1200,250)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
NovelImage = Image.open(bio)
NovelImage.save('SimpleReactionOverviewBlack.pdf',dpi=(2400,2400))
NovelImage
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x250>

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C=C(CC(=O)O)C(=O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1200,250)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.9215686274509803,0.49019607843137253,0.23529411764705882)})
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
NovelImage = Image.open(bio)
NovelImage.save('SimpleReactionOverviewOrange.pdf',dpi=(1200,1200))
NovelImage
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x250>

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C=C(CC(=O)O)C(=O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1200,250)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.11372549019607843,0.6941176470588235,0.9294117647058824)})
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
NovelImage = Image.open(bio)
NovelImage.save('SimpleReactionOverviewBlue.pdf',dpi=(1200,1200))
NovelImage
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x250>

# %% [markdown]
# # Simple Linear Reaction

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('CC(O)CO.C(CC(=O)O)C(=O)O>>CC(CO-*)OC(=O)CCC(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1600,600)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
Image.open(bio)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x600>

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('CC(O)CO.C(CC(=O)O)C(=O)O>>CC(CO-*)OC(=O)CCC(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1600,600)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.9215686274509803,0.49019607843137253,0.23529411764705882)})
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
Image.open(bio)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x600>

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('CC(O)CO.C(CC(=O)O)C(=O)O>>CC(CO-*)OC(=O)CCC(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1600,600)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.11372549019607843,0.6941176470588235,0.9294117647058824)})
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
Image.open(bio)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x600>

# %% [markdown]
# # Alberts Reaction

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>OC(CC(=O)O-*)(CC(=O)OCC(CO-*)O-*)C(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1600,600)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
Image.open(bio)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x600>

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>OC(CC(=O)O-*)(CC(=O)OCC(CO-*)O-*)C(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1600,600)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.9215686274509803,0.49019607843137253,0.23529411764705882)})
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
Image.open(bio)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x600>

# %%
from rdkit.Chem import AllChem as AllChem
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>OC(CC(=O)O-*)(CC(=O)OCC(CO-*)O-*)C(=O)O-*.O',useSmiles=True)
d2d = Draw.MolDraw2DCairo(1600,600)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.11372549019607843,0.6941176470588235,0.9294117647058824)})
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
bio = BytesIO(d2d.GetDrawingText())
Image.open(bio)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x600>

# %% [markdown]
# # High Resolution Images from SVGs

# %%
from IPython.display import SVG
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C=C(CC(=O)O)C(=O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*.O',useSmiles=True)
d2d = Draw.rdMolDraw2D.MolDraw2DSVG(1000, 300) 
d2d.DrawReaction(rxn)
dopts = d2d.drawOptions()
dopts.useBWAtomPalette()
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
f = open("Rxn1.svg", "x")
f.write(svg)
svg = d2d.GetDrawingText()
SVG(svg.replace('svg:', ''))

# %%
from IPython.display import SVG
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C=C(CC(=O)O)C(=O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*.O',useSmiles=True)
d2d = Draw.rdMolDraw2D.MolDraw2DSVG(1000, 300) 
d2d.DrawReaction(rxn)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.9215686274509803,0.49019607843137253,0.23529411764705882)})
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
f = open("Rxn2.svg", "x")
f.write(svg)
svg = d2d.GetDrawingText()
SVG(svg.replace('svg:', ''))

# %%
from IPython.display import SVG
rxn = AllChem.ReactionFromSmarts('C(C(CO)O)O.C=C(CC(=O)O)C(=O)O.C(C(=O)O)C(CC(=O)O)(C(=O)O)O>>*-OC(COC(=O)CC(CC(=O)O-*)C(=O)O-*)COC(=O)C(=C)CC(=O)O-*.O',useSmiles=True)
d2d = Draw.rdMolDraw2D.MolDraw2DSVG(1000, 300) 
d2d.DrawReaction(rxn)
dopts = d2d.drawOptions()
dopts.updateAtomPalette({8:(0.11372549019607843,0.6941176470588235,0.9294117647058824)})
d2d.DrawReaction(rxn)
d2d.FinishDrawing()
f = open("Rxn3.svg", "x")
f.write(svg)
svg = d2d.GetDrawingText()
SVG(svg.replace('svg:', ''))
