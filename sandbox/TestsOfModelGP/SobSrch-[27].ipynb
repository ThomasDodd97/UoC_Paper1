# %%
import numpy as np
import pandas as pd
from types import resolve_bases
import pickle
import plotly.express as px
from SamplingMethods import Sampler_class
from ax.api.client import Client

# %%
client = Client()
client = client.load_from_json_file("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/Sandbox/Modelling/ModelMk16.json")
client.get_next_trials(max_trials=1)
# Out:
# /Users/thomasdodd/miniconda3/envs/ax1_env/lib/python3.12/site-packages/botorch/optim/optimize.py:677: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .')]
# Trying again with a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# /Users/thomasdodd/miniconda3/envs/ax1_env/lib/python3.12/site-packages/botorch/optim/optimize.py:677: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# {57: {'s1': 0.33581323818628095,
#   's2': 0.6539883492066945,
#   'b1': 0.7760788853941598}}

# %%
trials = 600

X_lis = []
for i in range(trials):
    sampler = Sampler_class()
    Parameters_lis = [
        {"name":"x1", "type":"range","bounds":[0,1],"value_type":"float"},
        {"name":"x2", "type":"range","bounds":[0,1],"value_type":"float"},
        {"name":"x3", "type":"range","bounds":[0,1],"value_type":"float"}
    ]
    for i in range(100):
        X = sampler.three.QuasirandomSampler3D_func(27,Parameters_lis).T
        if np.shape(X) != (0,3):
            break
    X_lis.append(X)

y_max_lis = []
for X in X_lis:
    y_pred_lis = []
    for row in X:
        s1 = row[0]
        s2 = row[1]
        b1 = row[2]
        y_pred_lis.append(client.predict([{"s1":s1,"s2":s2,"b1":b1}])[0]["t1"][0])
    y_max_lis.append(np.max(np.array(y_pred_lis)))

y_max_arr = np.array(y_max_lis)
print(y_max_arr.tolist())
print(np.average(y_max_arr))
# Out:
# [15.841038506443482, 15.92882746164452, 14.135831774454333, 14.784919825435553, 15.507897974480688, 15.16983376523292, 14.533393739404856, 15.282793146113155, 14.745782278560824, 14.837208660795998, 14.140472811615954, 14.287311652204451, 14.165601865629183, 15.789860620756397, 15.390803896995484, 14.254813557318357, 16.210485485538694, 14.351022849225053, 14.79249622798701, 16.756880403184375, 15.072827562236412, 14.879513705743266, 14.756624576841817, 15.035500933880796, 16.40162349546904, 14.554727203758596, 13.931603509346639, 15.69890799306039, 15.568468023462236, 14.925749529256194, 14.416357482785935, 15.029160027946885, 16.734854277272383, 14.43908984764576, 17.33536336840776, 14.221175643522876, 14.177714594058772, 14.692571428085323, 14.255490821783106, 16.666389110815683, 15.516205863165188, 15.286805946732171, 15.360944702675848, 14.578358753654264, 14.31644455471477, 14.89959762959293, 15.301925095431232, 14.084871805830387, 14.846010141860393, 14.263143782626766, 14.361857671004048, 15.588654561012918, 15.00363907242522, 14.204327952368848, 16.2833941712249, 14.052787123163343, 14.784905250569109, 14.634255838892887, 15.542799924641676, 15.566824270731917, 14.880716594838681, 15.245975686790219, 14.85915685302656, 14.540600031514545