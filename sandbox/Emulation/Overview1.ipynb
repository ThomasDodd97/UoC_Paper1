# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rc('font',family='Times New Roman')

# %%
# Gp_Ma05
Gp_Ma05_RMSE = 1.416
Gp_Ma05_MSE = 2.005

# Gp_Ma15
Gp_Ma15_RMSE = 1.435
Gp_Ma15_MSE = 2.058

# Gp_Ma25
Gp_Ma25_RMSE = 1.444
Gp_Ma25_MSE = 2.085

# Gp_Rbf
Gp_Rbf_RMSE = 1.414
Gp_Rbf_MSE = 1.999

# Xgb
Xgb_RMSE = 1.508
Xgb_MSE = 2.274

Models_Names = ["Gp_Ma05","Gp_Ma15","Gp_Ma25","Gp_Rbf","Xgb"]
Models_RMSEs = [Gp_Ma05_RMSE,Gp_Ma15_RMSE,Gp_Ma25_RMSE,Gp_Rbf_RMSE,Xgb_RMSE]
Models_MSEs = [Gp_Ma05_MSE,Gp_Ma15_MSE,Gp_Ma25_MSE,Gp_Rbf_MSE,Xgb_MSE]
print(Models_Names)
print(Models_RMSEs)
print(Models_MSEs)
# Out:
# ['Gp_Ma05', 'Gp_Ma15', 'Gp_Ma25', 'Gp_Rbf', 'Xgb']
# [1.416, 1.435, 1.444, 1.414, 1.508]
# [2.005, 2.058, 2.085, 1.999, 2.274]

# %%
# GP_M05
Pr_GpMa05 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M05/DataGenerated/pseudorandom_27.pkl")[0].tolist()
Qr_GpMa05 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M05/DataGenerated/quasirandom_27.pkl")[0].tolist()
Se_GpMa05_Mipt = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M05/DataGenerated/normal_MIPT_9_27_3.pkl")[0].tolist()
Se_GpMa05_BayPi =  pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M05/DataGenerated/normal_PI_9_27_3.pkl")[0].tolist()
Se_GpMa05_BayEi = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M05/DataGenerated/normal_EI_9_27_3.pkl")[0].tolist()

# GP_M15
Pr_GpMa15 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M15/DataGenerated/pseudorandom_27.pkl")[0].tolist()
Qr_GpMa15 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M15/DataGenerated/quasirandom_27.pkl")[0].tolist()
Se_GpMa15_Mipt = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M15/DataGenerated/normal_MIPT_9_27_3.pkl")[0].tolist()
Se_GpMa15_BayPi =  pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M15/DataGenerated/normal_PI_9_27_3.pkl")[0].tolist()
Se_GpMa15_BayEi = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M15/DataGenerated/normal_EI_9_27_3.pkl")[0].tolist()

# GP_M25
Pr_GpMa25 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M25/DataGenerated/pseudorandom_27.pkl")[0].tolist()
Qr_GpMa25 = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M25/DataGenerated/quasirandom_27.pkl")[0].tolist()
Se_GpMa25_Mipt = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M25/DataGenerated/normal_MIPT_9_27_3.pkl")[0].tolist()
Se_GpMa25_BayPi =  pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M25/DataGenerated/normal_PI_9_27_3.pkl")[0].tolist()
Se_GpMa25_BayEi = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_M25/DataGenerated/normal_EI_9_27_3.pkl")[0].tolist()

# GP_RBF
Pr_GpRbf = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_RBF/DataGenerated/pseudorandom_27.pkl")[0].tolist()
Qr_GpRbf = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_RBF/DataGenerated/quasirandom_27.pkl")[0].tolist()
Se_GpRbf_Mipt = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_RBF/DataGenerated/normal_MIPT_9_27_3.pkl")[0].tolist()
Se_GpRbf_BayPi =  pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_RBF/DataGenerated/normal_PI_9_27_3.pkl")[0].tolist()
Se_GpRbf_BayEi = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelGP_RBF/DataGenerated/normal_EI_9_27_3.pkl")[0].tolist()

# XGB
Pr_Xgb = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelXG/DataGenerated/pseudorandom_27.pkl")[0].tolist()
Qr_Xgb = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelXG/DataGenerated/quasirandom_27.pkl")[0].tolist()
Se_Xgb_Mipt = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelXG/DataGenerated/normal_MIPT_9_27_3.pkl")[0].tolist()
Se_Xgb_BayPi =  pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelXG/DataGenerated/normal_PI_9_27_3.pkl")[0].tolist()
Se_Xgb_BayEi = pd.read_pickle(filepath_or_buffer="/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper1/sandbox/Emulation/TestStoichModelXG/DataGenerated/normal_EI_9_27_3.pkl")[0].tolist()

# %%
GpMa05 = [Pr_GpMa05,Qr_GpMa05,Se_GpMa05_Mipt,Se_GpMa05_BayPi,Se_GpMa05_BayEi]
GpMa15 = [Pr_GpMa15,Qr_GpMa15,Se_GpMa15_Mipt,Se_GpMa15_BayPi,Se_GpMa15_BayEi]
GpMa25 = [Pr_GpMa25,Qr_GpMa25,Se_GpMa25_Mipt,Se_GpMa25_BayPi,Se_GpMa25_BayEi]
GpRbf = [Pr_GpRbf,Qr_GpRbf,Se_GpRbf_Mipt,Se_GpRbf_BayPi,Se_GpRbf_BayEi]
Xgb = [Pr_Xgb,Qr_Xgb,Se_Xgb_Mipt,Se_Xgb_BayPi,Se_Xgb_BayEi]

Datasets = [GpMa05,GpMa15,GpMa25,GpRbf,Xgb]

# %%
DatasetsMeans = []
for dataset in Datasets:
    DatasubsetMeans = []
    for datasubset in dataset:
        DatasubsetMeans.append(np.mean(datasubset))
    DatasetsMeans.append(DatasubsetMeans)
DatasetsMeans = np.array(DatasetsMeans)

# %%
DataPoints = []
EmulatorTypes = []
OptimisationTypes = []
for FirstCounter,dataset in enumerate(Datasets):
    # e.g. dataset = GpMa05
    if FirstCounter == 0:
        EmulatorType = "Gp_Ma05"
    elif FirstCounter == 1:
        EmulatorType = "Gp_Ma15"
    elif FirstCounter == 2:
        EmulatorType = "Gp_Ma25"
    elif FirstCounter == 3:
        EmulatorType = "Gp_Rbf"
    elif FirstCounter == 4:
        EmulatorType = "Xgb"
    for SecondCounter,datasubset in enumerate(dataset):
        # e.g. datasubset = Pr_GpMa05
        if SecondCounter == 0:
            OptimisationType = "Pseudorandom"
        elif SecondCounter == 1:
            OptimisationType = "Quasirandom"
        elif SecondCounter == 2:
            OptimisationType = "Sequential MIPT"
        elif SecondCounter == 3:
            OptimisationType = "Sequential PI"
        elif SecondCounter == 4:
            OptimisationType = "Sequential EI"
        for DataPoint in datasubset:
            DataPoints.append(DataPoint)
            EmulatorTypes.append(EmulatorType)
            OptimisationTypes.append(OptimisationType)

# %%
d = {"DataPoints":DataPoints,"EmulatorTypes":EmulatorTypes,"OptimisationTypes":OptimisationTypes}
df = pd.DataFrame(data=d)
df
# Out:
#        DataPoints EmulatorTypes OptimisationTypes
# 0       15.855823       Gp_Ma05      Pseudorandom
# 1       13.707338       Gp_Ma05      Pseudorandom
# 2       13.872389       Gp_Ma05      Pseudorandom
# 3       13.656042       Gp_Ma05      Pseudorandom
# 4       14.405798       Gp_Ma05      Pseudorandom
# ...           ...           ...               ...
# 24995   18.626217           Xgb     Sequential EI
# 24996   16.349613           Xgb     Sequential EI
# 24997   16.545218           Xgb     Sequential EI
# 24998   15.394300           Xgb     Sequential EI
# 24999   13.758430           Xgb     Sequential EI
#
# [25000 rows x 3 columns]

# %%
SomeNumbers = []
for i in DatasetsMeans:
    for j in i:
        SomeNumbers.append(j)
OtherNumbers = [0,1,2,3,4]
SomeMoreNumbers = [-0.32,-0.16,0,0.16,0.32]
LastOfTheNumbers = []
for i in OtherNumbers:
    for j in SomeMoreNumbers:
        LastOfTheNumbers.append(i+j)

# %%
plt.gcf().set_size_inches(10.25, 4)
ax = sns.boxplot(data=df,x="EmulatorTypes", y="DataPoints", hue="OptimisationTypes")
sns.move_legend(ax,loc="upper left", bbox_to_anchor=(-0.05, 1.2),ncols=5)
ax.scatter(x=LastOfTheNumbers,y=SomeNumbers,marker="D",s=15,color="white",zorder=4,label="Mean",edgecolors="black")
ax.scatter(x=[0],y=[0],marker=".",s=130,color="white",edgecolor="black",label="Outlier")
ax.set_xticks(range(5))
ax.set_xticklabels([r"$\mathcal{GP}$"+"\nMatérn Kernel\n"+r"$\nu=0.5$",
                    r"$\mathcal{GP}$"+"\nMatérn Kernel\n"+r"$\nu=1.5$",
                    r"$\mathcal{GP}$"+"\nMatérn Kernel\n"+r"$\nu=2.5$",
                    r"$\mathcal{GP}$"+"\n Radial Basis Function",
                    "XGBoost"])
ax.set_xlabel("Emulator Type",fontsize=13)
ax.set_ylabel(r'Best Percentage Mass Loss, $\Delta$m$^\circ_\%$ (%)      ',fontsize=13)
ax.legend(bbox_to_anchor=(1.01, 1.2),ncols=7)
ax.set_ylim(10,20)
plt.tight_layout()
plt.savefig(fname='ComputationalResultOverview.png',dpi=1000,format='png')

# %%
plt.gcf().set_size_inches(10, 4)
sns.catplot(data=df, kind="strip",x="OptimisationTypes",hue="OptimisationTypes", y="DataPoints", col="EmulatorTypes",aspect=.5,s=0.5)
